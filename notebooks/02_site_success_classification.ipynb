# %% [markdown]
# # Site Success Classification
#
# Classify whether a site will average at least 1.5 enrolled patients per site-month (`successful_site`) using only features known at/before activation. Canonical implementation: `scripts/model_site_success.py` (logistic regression vs. gradient boosting, with calibration diagnostics in `outputs/calibration_plot.png`).

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/sites.csv')
enrollment = pd.read_csv('../data/enrollment.csv')
sites.head()
