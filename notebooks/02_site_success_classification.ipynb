# %% [markdown]
# # Site Success Classification
#
# Classify whether a site will hit >=80% of its enrollment target (sites.site_success) using site-level features known at or before activation.

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/raw/sites.csv')
patients = pd.read_csv('../data/raw/patients.csv')
events = pd.read_csv('../data/raw/screening_events.csv')
sites.head()
