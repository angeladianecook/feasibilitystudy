# %% [markdown]
# # Enrollment Prediction
#
# Predict a site's enrolled-patient count over its first 3 months of study participation (`patients_enrolled_3mo`, aggregated from `data/enrollment.csv`) from site features known at/before activation in `data/sites.csv`. Canonical implementation: `scripts/model_enrollment.py` (OLS vs. Poisson vs. negative binomial; results in `outputs/enrollment_model_summary.md`).

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/sites.csv')
enrollment = pd.read_csv('../data/enrollment.csv')
sites.head()
