# %% [markdown]
# # Enrollment Prediction
#
# Predict site- and study-level enrollment counts/rates from site features and early screening-funnel activity (data/raw/sites.csv, patients.csv, screening_events.csv).

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/raw/sites.csv')
patients = pd.read_csv('../data/raw/patients.csv')
events = pd.read_csv('../data/raw/screening_events.csv')
sites.head()
