# %% [markdown]
# # Leakage Stress-Testing
#
# Deliberately probe the enrollment-prediction and site-success models for target leakage and temporal leakage (e.g. features derived from post-outcome data), and show how performance collapses once leakage is removed.

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/raw/sites.csv')
patients = pd.read_csv('../data/raw/patients.csv')
events = pd.read_csv('../data/raw/screening_events.csv')
sites.head()
