# %% [markdown]
# # Leakage Stress-Testing
#
# Re-examine the enrollment and site-success models for target leakage, temporal leakage, study leakage, generalization gaps, missing-data behavior, and bias, then show what real leakage looks like when deliberately introduced. Canonical implementation: `scripts/stress_test.py` (six audits) and `scripts/leakage_demo.py` (before/after AUC with a feature engineered from the future outcome).

# %%
import pandas as pd
import numpy as np

studies = pd.read_csv('../data/studies.csv')
sites = pd.read_csv('../data/sites.csv')
enrollment = pd.read_csv('../data/enrollment.csv')
sites.head()
