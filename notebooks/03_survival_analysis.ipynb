# %% [markdown]
# # Survival Analysis
#
# Time-to-event modeling (Kaplan-Meier, Cox PH) on time to a 20-patient enrollment milestone per site (`time_to_target` / `target_reached`, restructured from `data/enrollment.csv`). Canonical implementation: `scripts/survival_analysis.py` (KM curve in `outputs/km_curve.png`, Cox PH hazard ratios printed to console).

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/sites.csv')
enrollment = pd.read_csv('../data/enrollment.csv')
sites.head()
