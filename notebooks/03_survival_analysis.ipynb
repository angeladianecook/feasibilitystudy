# %% [markdown]
# # Survival Analysis
#
# Time-to-event modeling (Kaplan-Meier, Cox PH) on randomized patients using time_to_event_days / event_observed, comparing treatment vs. control arms.

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/raw/sites.csv')
patients = pd.read_csv('../data/raw/patients.csv')
events = pd.read_csv('../data/raw/screening_events.csv')
sites.head()
