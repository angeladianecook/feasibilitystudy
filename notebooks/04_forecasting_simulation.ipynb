# %% [markdown]
# # Forecasting & Simulation
#
# Forecast one study's monthly enrollment (exponential smoothing and ARIMA) and Monte Carlo-simulate time to a 500-patient target under site-activation-delay scenarios. Canonical implementation: `scripts/forecast_and_simulate.py` (fan chart in `outputs/monte_carlo_fanchart.png`).

# %%
import pandas as pd
import numpy as np

studies = pd.read_csv('../data/studies.csv')
sites = pd.read_csv('../data/sites.csv')
enrollment = pd.read_csv('../data/enrollment.csv')
studies.head()
