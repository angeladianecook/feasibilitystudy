# %% [markdown]
# # Forecasting & Simulation
#
# Forecast monthly enrollment trajectories and simulate trial completion timelines under different site-activation scenarios.

# %%
import pandas as pd
import numpy as np

sites = pd.read_csv('../data/raw/sites.csv')
patients = pd.read_csv('../data/raw/patients.csv')
events = pd.read_csv('../data/raw/screening_events.csv')
sites.head()
